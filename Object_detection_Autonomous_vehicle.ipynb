# %% [markdown]
# # Installation and imports

# %%
# !pip install utils
from utils import *
import random
import numpy as np
import pandas as pd

import os
import shutil
import glob
from pathlib import Path
import pickle

import seaborn as sns
from matplotlib import pyplot as plt

import glob
from IPython.display import Image, display, clear_output

import torch

random.seed(42)

# %%
# !git clone https://github.com/ultralytics/yolov5
# !pip install -qr yolov5/requirements.txt
# %cd yolov5

import torch
#from IPython.display import Image, clear_output
#from utils.google_utils import gdrive_download

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.0+cu111 (Tesla P100-PCIE-16GB)

# %% [markdown]
# # Experiments

# %%
#If you want to use wandb

#!pip install wandb

#!wandb login #insert your API Key

# %% [markdown]
# If you want to use the embedded augmentation method of Yolo, run the code below

# %%
#!pip install -U albumentations

# %% [markdown]
# If you want to use the cost function Focal Loss, change the hyperparameter fl_gamma in the hyp.scratch.yaml file to a value bigger than 0.

# %% [markdown]
# ## Experiment 1
# Batch: 64 <br>
# Optmizer: SGD <br>
# Epochs: 120

# %% [markdown]
# **Training**

# %%
# Experiment 1

# %%time
# %cd /content/yolov5/
#!python train.py --img 416 --batch 16 --epochs 20 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# !python train.py --img 416 --batch 64 --epochs 10 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-0-g956be8e torch 1.9.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# ...

# %%
# Experiment 1 
# time its performance
# %%time
# %cd /content/yolov5/
#!python train.py --img 416 --batch 16 --epochs 20 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# !python train.py --img 416 --batch 64 --epochs 10 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results4/weights/last.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results4/weights/last.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=10, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %%
# Experiment 1 - 120 Epochs
# time its performance
# %%time
# %cd /content/yolov5/
#!python train.py --img 416 --batch 16 --epochs 20 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# !python train.py --img 416 --batch 64 --epochs 31 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results6/weights/best.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results6/weights/best.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=31, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results9/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results9/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results9/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results9/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-96-g8df64a9 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %%
#!python val.py --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results9/weights/best.pt' --data coco.yaml --img 640 --half

# %% [markdown]
# ## Experiment 1 - retry

# %% [markdown]
# Batch: 64 <br>
# Optmizer: SGD <br>
# Epoch : 120
#
# Training for 120 epoch can be done all at once or training n times, where the sum of epoch is equal to 120 and the next training starts from the best found before

# %% [markdown]
# **Training**

# %%
# %%time
# %cd /content/yolov5/
#!python train.py --img 416 --batch 16 --epochs 20 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# !python train.py --img 416 --batch 64 --epochs 120 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# ...
# train: weights=, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=120, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-103-g7a39803 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results116/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment1/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results116/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment1/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-155-gdc54ed5 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 2
# Batch: 64 <br>
# Optimizer: Adam <br>
# Epoch: 120

# %% [markdown]
# **Training**

# %%
# %%time
# %cd /content/yolov5/
#!python train.py --img 416 --batch 16 --epochs 20 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# !python train.py --img 416 --batch 64 --epochs 120 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=120, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-96-g8df64a9 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 89 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results10/weights/best.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 2
# wandb: You chose 'Use an existing W&B account'
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 23 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results11/weights/best.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results11/' --adam --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results11/weights/best.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=23, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results11/, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %%
# Out:
# /content/yolov5
# ...
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 2
# wandb: You chose 'Use an existing W&B account'
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results115/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results115/Val/'
# Out:
# ...
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results115/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results115/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-103-g7a39803 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 2 - Retry

# %%
# %%time
# %cd /content/yolov5/
#!python train.py --img 416 --batch 16 --epochs 20 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# !python train.py --img 416 --batch 64 --epochs 120 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# ...
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 2
# wandb: You chose 'Use an existing W&B account'
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results119/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment2/Val/'
# Out:
# ...
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results119/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment2/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-156-g95c7bc2 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 3
# Batch: 64 <br>
# Epoch: 120 <br>
# Optmizer: SGD <br>
# Loss Function: Focal Loss <br>
# Augmentation: False

# %%
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 64 --epochs 120 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# ...
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 2
# wandb: You chose 'Use an existing W&B account'
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results126/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment9/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results126/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment9/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-156-g95c7bc2 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 4
# Batch: 64 <br>
# Epoch: 120 <br>
# Optmizer: Adam <br>
# Augmentation: False <br>
# Loss function: Focal Loss

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 56 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results14345/weights/last.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# ...
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results14345/weights/last.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=56, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results14346/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment10/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results14346/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment10/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 5
#
# Optimizer: SGD <br>
# Epoch: 200 <br>
# Batch: 64 <br>
# Augmentation: False <br>
# Loss Function: BCEWithLogitsLoss

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 200 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# ...
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=200, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-155-gdc54ed5 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results129/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment11/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results129/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment11/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-156-g95c7bc2 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 6
# Optmizer: Adam <br>
# Epoch: 200  <br>
# Batch: 64   <br>
# Loss: BCEWithLogitsLoss <br>
# Augmentation: False

# %%
# !pip uninstall albumentations
# Out:
# Found existing installation: albumentations 1.1.0
# Uninstalling albumentations-1.1.0:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/albumentations-1.1.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/albumentations/*
# Proceed (y/n)? y
#   Successfully uninstalled albumentations-1.1.0

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 80 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results119/weights/best.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results119/weights/best.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=80, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (7/7), done.
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results131/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment12/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results131/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment12/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 7
#
# Batch: 64 <br>
# Epoch: 240 <br>
# Optmizer: SGD <br>
# Loss Function: BCEWithLogits <br>
# Augmentation: False

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 40 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results129/weights/last.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results129/weights/last.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=40, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 40 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results129/weights/best.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results129/weights/best.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=40, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results134/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment13/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results134/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment13/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 8
#
# Batch: 64 <br>
# Epoch: 240 <br>
# Optmizer: Adam <br>
# Loss Function: BCEWithLogits <br>
# Augmentaiton: False

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 40 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results131/weights/best.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results131/weights/best.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=40, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results135/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment14/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results135/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment14/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 9
# Batch: 64 <br>
# Epoch: 200 <br>
# Optmizer: SGD <br>
# Loss Function: Focal Loss <br>
# Augmentation: False

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 80 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results126/weights/best.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results126/weights/best.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=80, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results138/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment15/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results138/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment15/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 10
# Batch: 64 <br>
# Epoch: 240 <br>
# Optmizer: SGD <br>
# Loss Function: Focal Loss <br>
# Augmentation: False

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 40 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results136/weights/best.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# ...
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results136/weights/best.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=40, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results140/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment16/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results140/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment16/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 11
# Batch: 64 <br>
# Epoch: 200 <br>
# Optmizer: Adam <br>
# Loss Function: Focal Loss <br>
# Augmentation: False

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 200 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results143/weights/last.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results143/weights/last.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=85, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results143/, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %% [markdown]
# Retesting the 200 epoch - Starting from the 120 previous

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 81 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results14346/weights/best.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results14346/weights/best.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=81, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results1433/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment17/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results1433/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment17/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# Second validation

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results14347/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment17/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results14347/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment17/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-163-gd95978a torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 12
# Batch: 64 <br>
# Epoch: 240 <br>
# Optmizer: Adam <br>
# Loss Function: Focal Loss <br>
# Augmentation: False

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 40 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results14344/weights/last.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results1433/weights/best.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=40, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results1434, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 240 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=240, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-163-gd95978a torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 240 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results14348/weights/last.pt' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results14348/' --optimizer 'Adam' --cache
# Out:
# /content/yolov5
# ...
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=/content/drive/MyDrive/USP/dataExploration/yolov5s_results14348/weights/last.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=240, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=Adam, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results14348/, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results14344/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment18/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results14344/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment18/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-159-gdb6ec66 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 13

# %% [markdown]
# Otimizador: SGD <br>
# Epoch:120  <br>
# Batch: 64  <br>
# Tipo: treinamento <br>
# Augmentation: enabled <br>

# %%
# !pip install -U albumentations

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 120 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# ...
# train: weights=, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=120, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/ultralytics/yolov5
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results117/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment3/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results117/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment3/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-156-g95c7bc2 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 14
#
# Batch: 64  <br>
# Epoch: 120  <br>
# Otimizador: Adam <br>
# Tipo: treinamento <br>
# Augmentation: true <br>

# %% [markdown]
# **Training**

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 120 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# ...
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=120, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results118/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment4/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results118/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment4/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-156-g95c7bc2 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 15
# Optimizer: SGD <br>
# Batch: 32 <br>
# Epoch: 120 <br>
# Algumentation: False

# %%
# %%time
# %cd /content/yolov5/
#!python train.py --img 416 --batch 16 --epochs 20 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# !python train.py --img 416 --batch 32 --epochs 120 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# ...
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 2
# wandb: You chose 'Use an existing W&B account'
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results121/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment5/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results121/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment5/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-156-g95c7bc2 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 16
# Batch: 32 <br>
# Optimizer: Adam <br>
# Epoch: 120 <br>
# Augmentation: false

# %%
# %%time
# %cd /content/yolov5/
#!python train.py --img 416 --batch 16 --epochs 20 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# !python train.py --img 416 --batch 32 --epochs 120 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=120, batch_size=32, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-127-g554f782 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results122/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment6/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results122/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment6/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-156-g95c7bc2 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 17
#
# Batch: 64 <br>
# Optimizer: SGD <br>
# Epoch: 240 <br>
# Augmentation: Enabled

# %%
# %%time
# %cd /content/yolov5/
#!python train.py --img 416 --batch 16 --epochs 20 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# !python train.py --img 416 --batch 64 --epochs 240 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --cache
# Out:
# /content/yolov5
# ...
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 2
# wandb: You chose 'Use an existing W&B account'
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# ...

# %% [markdown]
# **Validation**

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results124/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment7/Val/'
# Out:
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results124/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment7/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-156-g95c7bc2 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# ## Experiment 18
# Batch: 64 <br>
# Optmizer: Adam <br>
# Epoch: 240 <br>
# Augmentation: True

# %%
# %%time
# %cd /content/yolov5/

# !python train.py --img 416 --batch 64 --epochs 240 --data '/content/drive/MyDrive/USP/Model/data.yaml' --cfg '/content/yolov5/models/yolov5s.yaml' --weights '' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results' --adam --cache
# Out:
# /content/yolov5
# wandb: Currently logged in as: talles_nr (use `wandb login --relogin` to force relogin)
# train: weights=, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/drive/MyDrive/USP/Model/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=240, batch_size=64, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=True, sync_bn=False, workers=8, project=runs/train, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 4 (delta 3), reused 3 (delta 3), pack-reused 1
# Unpacking objects: 100% (4/4), done.
# ...

# %%
# !python val.py --data '/content/drive/MyDrive/USP/Model/data.yaml' --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results130/weights/best.pt' --img 416 --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment8/Val/'
# Out:
# ...
# val: data=/content/drive/MyDrive/USP/Model/data.yaml, weights=['/content/drive/MyDrive/USP/dataExploration/yolov5s_results130/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=/content/drive/MyDrive/USP/dataExploration/yolov5s_results/Experiment8/Val/, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-183-g33a67b4 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning '/content/drive/MyDrive/USP/export/test/labels.cache' images and labels... 8629 found, 0 missing, 0 empty, 0 corrupted: 100% 8629/8629 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/USP/export/test/images/1478021875081281646_jpg.rf.bEZPhuyXU5hIovwQSTIp.jpg: 1 duplicate labels removed
# ...

# %% [markdown]
# # How to detect objects on unseeing data having your model already trained

# %%
# !python detect.py --weights '/content/drive/MyDrive/USP/dataExploration/yolov5s_results4/weights/best.pt' --img 416 --conf 0.4 --source '/content/drive/MyDrive/USP/export/test/images/' --name '/content/drive/MyDrive/USP/dataExploration/yolov5s_results4/Test/'
